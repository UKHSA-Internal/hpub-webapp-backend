# %%
cd ../../..

# %% [markdown]
# ## Partial Service Disruption
#
# See: https://ukhsa.atlassian.net/wiki/spaces/HPP/pages/456230067/Partial+Disruption+Process+Flow

# %%
import json
import requests

# %%
import os

HPUB_BACKEND_BASE_URL = os.getenv('HPUB_BACKEND_BASE_URL', 'https://find-public-health-resources.service.gov.uk')
# HPUB_BACKEND_BASE_URL = 'https://hpub-dev.test-and-trace.nhs.uk/'
HPUB_BACKEND_SECRET_ACCESS_TOKEN = os.getenv('HPUB_BACKEND_SECRET_ACCESS_TOKEN')

# %% [markdown]
# ### Get access token

# %% [markdown]
# ### List all notifications

# %%
def list_notifications():
    url = f"{HPUB_BACKEND_BASE_URL}/api/v2/notifications/"

    headers = {
        'Authorization': f"Bearer {HPUB_BACKEND_SECRET_ACCESS_TOKEN}",
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    }

    response = requests.request("GET", url, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
from pprint import pprint

for notificaiton in list_notifications():
    pprint(notificaiton)
    print('---')

# %% [markdown]
# ### Planned Banner

# %%
def enable_planned_banner():
    url = "http://localhost:8080/api/v2/notifications/7937e917-10de-4eaf-a3fc-cb74e959b676/"

    payload = json.dumps({
    "is_enabled": False,
    "message": "",
    "start_at": None,
    "end_at": "2026-03-03T15:34:59.169008Z"
    })
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Content-Type': 'application/json'
    }

    response = requests.request("PUT", url, headers=headers, data=payload)
    response.raise_for_status()
    return response.json()

# %%
def schedule_planned_banner():
    url = "http://localhost:8080/api/v2/notifications/7937e917-10de-4eaf-a3fc-cb74e959b676/"

    payload = json.dumps({
    "is_enabled": False,
    "message": "",
    "start_at": None,
    "end_at": "2026-03-03T15:34:59.169008Z"
    })
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Content-Type': 'application/json'
    }

    response = requests.request("PUT", url, headers=headers, data=payload)
    response.raise_for_status()
    return response.json()

# %% [markdown]
# ### Unplanned Banner

# %%
def enable_planned_banner():
    pass

# %% [markdown]
# ### Custom Banner

# %%
def create_custom_banner():

    url = "http://localhost:8080/api/v2/notifications/"

    payload = json.dumps({
    "is_enabled": True,
    "message": "",
    "start_at": "2026-02-25T11:00:00Z",
    "end_at": "2026-02-25T17:00:00Z"
    })
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Content-Type': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data=payload)
    response.raise_for_status()
    return response.json()

# %%
# create_custom_banner()

# %% [markdown]
# ### Validate Frontend Notification

# %%
def get_notifications():
    url = f"{HPUB_BACKEND_BASE_URL}/api/v2/frontend/notifications/"

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    }

    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
get_notifications()
