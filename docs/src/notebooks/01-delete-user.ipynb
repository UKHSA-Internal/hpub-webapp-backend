# %%
cd ../../..

# %% [markdown]
# ## Delete User

# %%
def delete_user():
    import requests

    url = "http://localhost:8080/api/v2/users/de788e31-21ea-4550-8080-4f3ae95a72f3/"

    payload = {}
    headers = {}

    response = requests.request("DELETE", url, headers=headers, data=payload)

    print(response.text)
